# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from matplotlib.pyplot import figure

# %%
def logistic1(c1, q2):
    return ((q2/c1)**(1/2)-q2)

def logistic2(c1, q2):
    return ((q2/c1)**(1/2)-q2)

# %%
figure(num=None, figsize=(8, 8))
a=2
b=1

x = np.linspace(0, 1,num=1000)
y = logistic2(b, x)
fig, ax = plt.subplots(1, 1)
ax.plot(x,logistic2(b, y),  'b')
ax.plot(logistic1(a, x),y, 'k')
#ax.plot(logistic2(b, x),x,  'b')
#plt.ylim(0,0.127)
#plt.xlim(0.0,0.25)
plt.legend(fontsize=18)
plt.xlabel( "$\dot{\Theta}$ = Degree of product differentiation" )
plt.ylabel( "$\delta$ = Critical factor discount")
plt.legend(loc= "lower right")
plt.title("Fine rate= f = .05",fontsize = 11)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x = np.linspace(0, 1,num=1000)
y = np.linspace(0, 1,num=1000)
ax.plot(x, logistic1(a, y), 'k')
ax.plot(logistic2(b, x),x,  'b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11992/309953645.py in <module>
#       1 x = np.linspace(0, 1,num=1000)
#       2 y = np.linspace(0, 1,num=1000)
# ----> 3 ax.plot(x, logistic1(a, y), 'k')
#       4 ax.plot(logistic2(b, x),x,  'b')
#
# NameError: name 'ax' is not defined

# %%
def plot_system(r1,r2, x0, n, ax=None):
    # Plot the function and the
    # y=x diagonal line.
    t = np.linspace(0.00, 0.4,100)
    ax.plot(t,logistic1(r1, t),  'b', lw=2)
    ax.plot(logistic2(r2, t), t, 'k', lw=2)

    # Recursively apply y=f(x) and plot two lines:
    # (x, x) -> (x, y)
    # (x, y) -> (y, y)
    # x -> logistic2(r2, t)
    # y -> logistic1(r1,t)
    x1 = t[1]
    for i in range(n):
        x = logistic2(r2,x1)
        y = logistic1(r1,x)
        
        # Plot the two lines.
        ax.plot([x, x], [x1, y], 'k', lw=1) 
        ax.plot([x, logistic2(r2,y)], [y,y ], 'k', lw=1)
        # Plot the positions with increasing
        # opacity.
        ax.plot([x], [y], 'ok', ms=10,
                alpha=(i + 1) / n)
        x1 =  y

    ax.set_xlim(0,0.36)
    ax.set_ylim(0,0.091)
    ax.set_title(f"$r={r1:.1f}, \, x_0={t[1]:.1f}$")


fig, (ax1) = plt.subplots(1, figsize=(12, 6),
                               sharey=True)
plot_system(2.8,0.5, .1, 100, ax=ax1)
plot_system(3.5,2.5,.1, 100, ax=ax2)

# %%
np.random.random()
# Out:
# 0.3131716003412899

# %%
def logistic1(c1, q2):
    return ((q2/c1)**(1/2)-q2)

# %%
class secuenciaLogistica:
    """
    Modela el sistema dinámico descrito de la forma: x_{n+1} = f(r, x_n)
    """
    def __init__(self, fx):
        """
        Inicializa con x y r = 0 para una función fx arbitraria
        """
        self.x, self.r, self.fx = 0, 0, fx
    
    def actualizar(self):
        """
        Aplica el mapa de acuerdo a la función fx para obtener el siguiente termino de la iteración.
        Se asume que fx es una función de 2 argumentos: r y x.
        """
        self.x = self.fx(self.r, self.x)
    
    def generarSecuencia(self, n):
        "Genera y retorna una secuencia de longitud n para la función fx"
        xns=[]
        for i in range(n):
            xns.append(self.x)
            self.actualizar()
        return xns
    
    def diagBifurcacion(self, inicio, fin, paso, x0, n, ultimos, titulo='', aspecto=(10,7)):
        """
        Genera el diagrama de bifurcación de la función f(x) en el intervalo de r dado por [inicio, fin] 
        con pasos en r dados por `paso` usando una sucesión de `n` elementos. Luego toma los 
        `ultimos` elementos de la sucesión para incluirlos en la gráfica.
        Asigna un `titulo` a la gráfica si se le provee y emplea una relacion de aspecto `aspecto` si se
        le proveé.
        """
        import matplotlib.pyplot as plt
        self.r=inicio
        fig=plt.figure(figsize=aspecto)
        while self.r<fin:
            self.x=x0
            xns=self.generarSecuencia(n)
            self.r+=paso
            xfinales=xns[n-ultimos:]
            rs=[self.r for xs in xfinales]     
            plt.scatter(rs,xfinales, c='b', marker='o', s=0.1)
        plt.title(titulo, fontsize=24)
        plt.xlabel('$r$', fontsize=24)
        plt.ylabel('$x_n$\'s convergentes', fontsize=24)
        plt.xticks(fontsize=20)
        plt.yticks(fontsize=20)
        #plt.xlim(3.8,5)
        #plt.ylim(3.6,4.5)
        #plt.show()
        plt.savefig('diagramaBifurcacion.png')

# %%
#Define una funcion empleando la aplicacion logistica
aplLogistica = lambda r, x: r*x*(r-x) 
#Inicializamos una instancia de la clase con la función fx deseada.
secOriginal=secuenciaLogistica(aplLogistica)   
secOriginal.diagBifurcacion(0.02,7,0.000625,0.5,3000,100,titulo='$f(x_n)=rx_n(1-x_n)$',aspecto=(26.67,15))

# %%
#Define una funcion empleando la aplicacion logistica
aplLogistica = lambda r, x: r*x*(1/r-x) 
#Inicializamos una instancia de la clase con la función fx deseada.
secOriginal=secuenciaLogistica(aplLogistica)   
secOriginal.diagBifurcacion(0.02,7,0.000625,0.5,3000,100,titulo='$f(x_n)=rx_n(1-x_n)$',aspecto=(26.67,15))

# %%
#Define una funcion empleando la aplicacion logistica
aplLogistica = lambda r, x: r*x*(1-x) 
#Inicializamos una instancia de la clase con la función fx deseada.
secOriginal=secuenciaLogistica(aplLogistica)   
secOriginal.diagBifurcacion(0.001,0.02,0.000625,0.5,3000,100,titulo='$f(x_n)=rx_n(1-x_n)$',aspecto=(26.67,15))

# %%
from numpy import sin
reglaSin = lambda r,x: r*sin(x)*(1-sin(x)) 
secSin=secuenciaLogistica(reglaSin)
secSin.diagBifurcacion(0.0001,1,0.0025,0.01,1000,50,titulo='$f(x_n)=sin(rx_n)$',aspecto=(26.67,15))

# %%
n = 10000
r = np.linspace(2, 4, n)
iterations = 1000
last = 100
x = 1e-1 * np.ones(n)
lyapunov = np.zeros(n)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9),
                               sharex=True)
for i in range(iterations):
    x = (x/r)**(1/2)-x
    # We compute the partial sum of the
    # Lyapunov exponent.
    lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
    # We display the bifurcation diagram.
    if i >= (iterations - last):
        ax1.plot(r,x, ',k', alpha=.25)
#ax1.set_xlim(2.5, 4)
ax1.set_title("Bifurcation diagram")

# We display the Lyapunov exponent.
# Horizontal line.
ax2.axhline(0, color='k', lw=.5, alpha=.5)
# Negative Lyapunov exponent.
ax2.plot(r[lyapunov < 0],
         lyapunov[lyapunov < 0] / iterations,
         '.k', alpha=.5, ms=.5)
# Positive Lyapunov exponent.
ax2.plot(r[lyapunov >= 0],
         lyapunov[lyapunov >= 0] / iterations,
         '.r', alpha=.5, ms=.5)

#ax2.set_xlim(2.5, 4)
#ax2.set_ylim(-2, 1)
ax2.set_title("Lyapunov exponent")
plt.tight_layout()
# Out:
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: divide by zero encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2004868925.py:14: RuntimeWarning: invalid value encountered in log
#   lyapunov += np.log(abs((1/(4*r*x))**(1/2))-1)

# %%
import matplotlib.pyplot as plt
import numpy as np
R=np.linspace(0.0,1.0,100000)
X=[]
Y=[]
for r in R:
    X.append(r)
    x=np.random.random()
    for n in range(1000):
        x=(1/r)*x*(1-x)
    Y.append(x)
plt.plot(Y,X,ls=' ', marker=',')
plt.show()
# Out:
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2515252529.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   x=(1/r)*x*(1-x)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/2515252529.py:10: RuntimeWarning: overflow encountered in double_scalars
#   x=(1/r)*x*(1-x)

# %%
q2 = np.linspace(0, 1,num=1000)
q1 = []
c1 = 2

for i in q2:
    q1.append((i/c1)**(1/2)-i)


fig, ax = plt.subplots(1, 1)
ax.plot(q2, q1, 'k')
ax.plot(q1, q2, 'b')
plt.ylim(0,0.5)
plt.xlim(0.0,0.51)
# Out:
# (0.0, 0.51)

# %%
n = 10000
r = np.linspace(5.0, 9.0, n)

# %%
iterations = 1000
last = 100

# %%
x = 1e-5 * np.ones(n)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 9),
                               sharex=True)
for i in range(iterations):
    x =x**2*(1-2*r*x+r**2*x**2) #logistic1(r, x)
    # We compute the partial sum of the
    # Lyapunov exponent.
    lyapunov += np.log(abs(r - 2 * r * x))
    # We display the bifurcation diagram.
    if i >= (iterations - last):
        ax1.plot(r, x, ',k', alpha=.25)
ax1.set_xlim(2.5, 500)
ax1.set_title("Bifurcation diagram")

# We display the Lyapunov exponent.
# Horizontal line.
ax2.axhline(0, color='k', lw=.5, alpha=.5)
# Negative Lyapunov exponent.
ax2.plot(r[lyapunov < 0],
         lyapunov[lyapunov < 0] / iterations,
         '.k', alpha=.5, ms=.5)
# Positive Lyapunov exponent.
ax2.plot(r[lyapunov >= 0],
         lyapunov[lyapunov >= 0] / iterations,
         '.r', alpha=.5, ms=.5)
ax2.set_xlim(2.5, 500)
ax2.set_ylim(-2, 1)
ax2.set_title("Lyapunov exponent")
plt.tight_layout()

# %%
x0=-0.09  #Población inicial
n=100000  #Numero total de iteraciones
ultimos=50   #Términos que consideraremos para checar hacia donde converge la sucesión.

r=-2.9
fig=plt.figure()
while r<0: 
    xns=[x0]   #Lista donde se guardan los elementos de la sucesión.
    for i in range(n):
        xns.append((1/r)*xns[i]*(1-xns[i]))
    r+=0.005
    xfinales=xns[n-ultimos:]    #Los ultimos 50 valores de la sucesión.
    rs=[r for xs in xfinales]    #Una lista con el valor de r actual repetido 50 veces.
    plt.scatter(rs, xfinales, c='b', marker='o', s=0.1)
    
plt.xlabel('$r$', fontsize=14)
plt.ylabel('$x_n$\'s convergentes', fontsize=14)
#plt.show()
plt.savefig('logisticaOriginal.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
R=np.linspace(0.42,0.53,10000)
X=[]
Y=[]
for r in R:
    X.append(r)
    x=np.random.random()
    for n in range(1000):
        x=(x*(1/r)-x**2)**2
    Y.append(x)
plt.plot(X,Y,ls=' ', marker=',')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
R=np.linspace(0.53,4.5,10000)
X=[]
Y=[]
for r in R:
    X.append(r)
    x=np.random.random()
    for n in range(1000):
        x=(x*r-x**2)**2
    Y.append(x)
plt.plot(X,Y,ls=' ', marker=',')
plt.show()
# Out:
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/3585598345.py:10: RuntimeWarning: overflow encountered in double_scalars
#   x=(x*r-x**2)**2
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_16692/3585598345.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   x=(x*r-x**2)**2

# %%
import matplotlib.pyplot as plt
import numpy as np
R=np.linspace(0.5,0.9,10000)
X=[]
Y=[]
for r in R:
    X.append(r)
    x=np.random.random()
    for n in range(1000):
        x=(((x/((5.75*r)**2))**(1/4) - x**(1/2)))**2
    Y.append(x)
plt.plot(X,Y,ls=' ', marker=',')
plt.show()

# %%
from numpy import sin

# %%
import matplotlib.pyplot as plt
import numpy as np
R=np.linspace(0.01,0.9,10000)
X=[]
Y=[]
for r in R:
    X.append(r)
    x=np.random.random()
    for n in range(1000):
        x=(x-r*x**2)**2
    Y.append(x)
plt.plot(X,Y,ls=' ', marker=',')
plt.show()

# %%
np.random.random()
# Out:
# 0.7120225564861391

# %%
import matplotlib.pyplot as plt
import numpy as np
a=10
b=0.5
c1=3
c2=5
n=1000
x0 = 0.001
y0 = 0.001
R=np.linspace(0.0,0.5,1000000)
X=[]
Y1=[]
Y2=[]

for r in R:
    X.append(r)
    x=x0
    y=y0
    #x=np.random.random()
    for j in range(1000):
        xnext=x+r*x*(a-c1-2*b*x+b*y)
        ynext =(1/(2*b))*(a-c2-b*x) 
        x=xnext
        y=ynext
    Y1.append(xnext)
    Y2.append(ynext)
        
plt.plot(X,Y1,ls=' ', marker=',')
plt.plot(X,Y2,ls=' ', marker=',')
plt.show()
# Out:
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_12152/2075124063.py:22: RuntimeWarning: overflow encountered in double_scalars
#   xnext=x+r*x*(a-c1-2*b*x+b*y)

# %%
a=10
b=0.5
c1=3
c2=5
def system_equations(x, y, r):
    x_next = x+(r*x)*(a-c1-(2*b*x)- b* y)
    y_next = (1/(2*b))*(a-c2-b*x)
    return x_next, y_next

# Function to iterate the system
def iterate_system(x0, y0, r, num_iterations):
    x = np.zeros(num_iterations)
    y = np.zeros(num_iterations)
    x[0], y[0] = x0, y0
    for t in range(1, num_iterations):
        x[t], y[t] = system_equations(x[t-1], y[t-1], r)
    return x, y

# Parameters
r_values = np.linspace(0, 4, 100000)  # Range of parameter values for 'r'
x0, y0 = 0.1, 0.1  # Initial conditions
num_iterations = 1000  # Number of iterations

# Iterate the system for each value of 'r'
bifurcation_data1 = []
bifurcation_data2 = []
for r in r_values:
    x_traj, y_traj = iterate_system(x0, y0, r, num_iterations)
    bifurcation_data1.append((r, x_traj[-1]))
    bifurcation_data2.append((r, y_traj[-1]))

# Plot bifurcation diagram
plt.figure(figsize=(6, 6))
plt.scatter(*zip(*bifurcation_data1), s=1, c='black', marker='o')
plt.scatter(*zip(*bifurcation_data2), s=1, c='black', marker='o')
plt.xlabel('r')
plt.ylabel('x')
plt.title('Bifurcation Diagram')
plt.show()
# Out:
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_12152/2804624385.py:6: RuntimeWarning: overflow encountered in double_scalars
#   x_next = x+(r*x)*(a-c1-(2*b*x)- b* y)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_12152/2804624385.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   x_next = x+(r*x)*(a-c1-(2*b*x)- b* y)

# %%
a=10
b=0.5
c1=3
c2=5
def system_equations(x, y, r):
    x_next = x+(r*x)*(a-c1-(2*b*x)- b* y)
    y_next = (1/(2*b))*(a-c2-b*x)
    return x_next, y_next

# Function to iterate the system
def iterate_system(x0, y0, r, num_iterations):
    x = np.zeros(num_iterations)
    y = np.zeros(num_iterations)
    x[0], y[0] = x0, y0
    for t in range(1, num_iterations):
        x[t], y[t] = system_equations(x[t-1], y[t-1], r)
    return x, y

# Parameters
r_values = np.linspace(0, 4, 1000000)  # Range of parameter values for 'r'
x0, y0 = 0.1, 0.1  # Initial conditions
num_iterations = 1000  # Number of iterations

# Iterate the system for each value of 'r'
bifurcation_data1 = []
bifurcation_data2 = []
for r in r_values:
    x_traj, y_traj = iterate_system(x0, y0, r, num_iterations)
    bifurcation_data1.append((r, x_traj[-1]))
    bifurcation_data2.append((r, y_traj[-1]))

# Plot bifurcation diagram
plt.figure(figsize=(6, 6))
plt.scatter(*zip(*bifurcation_data1), s=1, c='black', marker='o')
plt.scatter(*zip(*bifurcation_data2), s=1, c='black', marker='o')
plt.xlabel('r')
plt.ylabel('x')
plt.title('Bifurcation Diagram')
plt.show()
# Out:
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_12152/535977251.py:6: RuntimeWarning: overflow encountered in double_scalars
#   x_next = x+(r*x)*(a-c1-(2*b*x)- b* y)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_12152/535977251.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   x_next = x+(r*x)*(a-c1-(2*b*x)- b* y)

# %%
a=10
b=0.5
c1=3
c2=5
def system_equations(x, y, r):
    x_next = x+(r*x)*(a-c1-(2*b*x)- b* y)
    y_next = (1/(2*b))*(a-c2-b*x)
    return x_next, y_next

# Function to iterate the system
def iterate_system(x0, y0, r, num_iterations):
    x = np.zeros(num_iterations)
    y = np.zeros(num_iterations)
    x[0], y[0] = x0, y0
    for t in range(1, num_iterations):
        x[t], y[t] = system_equations(x[t-1], y[t-1], r)
    return x, y

# Parameters
r_values = np.linspace(0, 4, 10000000)  # Range of parameter values for 'r'
x0, y0 = 0.1, 0.1  # Initial conditions
num_iterations = 1000  # Number of iterations

# Iterate the system for each value of 'r'
bifurcation_data1 = []
bifurcation_data2 = []
for r in r_values:
    x_traj, y_traj = iterate_system(x0, y0, r, num_iterations)
    bifurcation_data1.append((r, x_traj[-1]))
    bifurcation_data2.append((r, y_traj[-1]))

# Plot bifurcation diagram
plt.figure(figsize=(6, 6))
plt.scatter(*zip(*bifurcation_data1), s=1, c='black', marker='o')
plt.scatter(*zip(*bifurcation_data2), s=1, c='black', marker='o')
plt.xlabel('r')
plt.ylabel('x')
plt.title('Bifurcation Diagram')
plt.show()
# Out:
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_12152/2234258947.py:6: RuntimeWarning: overflow encountered in double_scalars
#   x_next = x+(r*x)*(a-c1-(2*b*x)- b* y)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_12152/2234258947.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   x_next = x+(r*x)*(a-c1-(2*b*x)- b* y)

# %%
def system_equations(x, y, r):
    x_next = r*y*(1-y)
    y_next = r*x*(1-x)
    return x_next, y_next

# Function to iterate the system
def iterate_system(x0, y0, r, num_iterations):
    x = np.zeros(num_iterations)
    y = np.zeros(num_iterations)
    x[0], y[0] = x0, y0
    for t in range(1, num_iterations):
        x[t], y[t] = system_equations(x[t-1], y[t-1], r)
    return x, y

# Parameters
r_values = np.linspace(0, 4, 10000)  # Range of parameter values for 'r'
x0, y0 = 0.1, 0.1  # Initial conditions
num_iterations = 10000  # Number of iterations

# Iterate the system for each value of 'r'
bifurcation_data = []
for r in r_values:
    x_traj, y_traj = iterate_system(x0, y0, r, num_iterations)
    bifurcation_data.append((r, x_traj[-1]))

# Plot bifurcation diagram
plt.figure(figsize=(6, 6))
plt.scatter(*zip(*bifurcation_data), s=1, c='blue', marker='o')
plt.xlabel('r')
plt.ylabel('x')
plt.title('Bifurcation Diagram')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def system_equations(x, y, r):
    x_next = x + r * x * (10 - 3 - 2 * 0.5 * x - 0.5 * y)
    y_next =  (10 - 5 - 0.5 * x)
    return x_next, y_next

def lyapunov_exponent(x0, y0, r, num_iterations):
    x = x0
    y = y0
    lyapunov_sum = 0
    for _ in range(num_iterations):
        x_next, y_next = system_equations(x, y, r)
        jacobian = np.array([
            [r * (10 - 3 - 2 * 0.5 * x - 2 * r * 0.5 * y), -0.5 * r * x],
            [-0.25 / 0.5, 0]
        ])
        v = np.array([1, 0])  # Initial perturbation
        v = np.dot(jacobian, v) / np.linalg.norm(np.dot(jacobian, v))  # Normalize
        lyapunov_sum += np.log(np.abs(np.linalg.norm(np.dot(jacobian, v))))  # Accumulate sum of logarithms
        x, y = x_next, y_next
    lyapunov_exp = lyapunov_sum / num_iterations
    return lyapunov_exp

# Parameters
r_values = np.linspace(0, 4, 1000)  # Range of r values
x0, y0 = 0.1, 0.1  # Initial conditions
num_iterations = 1000  # Number of iterations per parameter value

# Compute Lyapunov exponent for each r value
lyapunov_exponents = []
for r in r_values:
    lyapunov_exponents.append(lyapunov_exponent(x0, y0, r, num_iterations))

# Plot the Lyapunov exponent
plt.figure(figsize=(10, 6))
plt.plot(r_values, lyapunov_exponents, color='blue', linewidth=1)
plt.xlabel('r')
plt.ylabel('Lyapunov Exponent')
plt.title('Lyapunov Exponent of the System of Difference Equations')
plt.grid(True)
plt.show()
# Out:
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_34060/1628069683.py:21: RuntimeWarning: divide by zero encountered in log
#   lyapunov_sum += np.log(np.abs(np.linalg.norm(np.dot(jacobian, v))))  # Accumulate sum of logarithms
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_34060/1628069683.py:5: RuntimeWarning: overflow encountered in double_scalars
#   x_next = x + r * x * (10 - 3 - 2 * 0.5 * x - 0.5 * y)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_34060/1628069683.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   x_next = x + r * x * (10 - 3 - 2 * 0.5 * x - 0.5 * y)
# C:\Users\crbw7\AppData\Local\Temp/ipykernel_34060/1628069683.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   [r * (10 - 3 - 2 * 0.5 * x - 2 * r * 0.5 * y), -0.5 * r * x],

# %%
x_{t+1}=x_{t}+rx_{t}(a-c₁-2bx_{t}-(1+α₁)by_{t})
    y_{t+1}=(1/(2b))(a-c₂-(1+α₂)bx_{t})
